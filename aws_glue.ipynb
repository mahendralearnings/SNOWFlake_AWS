# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://skphd.medium.com/aws-glue-interview-questions-and-answers-849135f1e6e4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://github.com/rdwr-vijaykumarb/DevOps-AWS-Interview-QA/blob/main/Terraform%20/Terraform%20Interview%20QA.md

# %% [markdown]
# https://aws.amazon.com/awstv/watch/1728674d388/
